# %% [markdown]
# # Inteligencia de Negocios: Laboratorio 1
# ## Integrantes: Grupo 17
#
# * Mariana Díaz Arenas - [m.diaza2](mailto:m.diaza2@uniandes.edu.co)
# * Esteban Gonzales Ruales - [e.gonzalez5](mailto:e.gonzalez5@uniandes.edu.co)
# * Juan Diego Yepes - [j.yepes](mailto:j.yepes@uniandes.edu.co)
#
#
# En el siguiente cuaderno de Jupyter implementamos la solución al siguiente laboratorio propuesto: [link](https://gitlab.virtual.uniandes.edu.co/ISIS3301/laboratorios/blob/master/202310/Lab%201%20-%20Clustering/Laboratorio1_enunciado.md)

# %% [markdown]
# # 1. Entendimiento de los datos

# %%
# Importación de librerías y creación del dataFrame

import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)

df_roads = pd.read_csv('./data/BiciAlpes.csv', index_col = 0, encoding = "latin1", sep = ";")

# Imprime el tamaño del dataframe
df_roads.shape
# Out:
# (5338, 14)

# %%
# Verificación de que se cargó correctamente
#TODO por qué sale ese Unnamed 14?
df_roads
# Out:
#         Number_of_Casualties    Day_of_Week  Road_Type  Speed_limit  \
# Time
# Mañana                     1    Día laboral          6         30.0
# Mañana                     1    Día laboral          6         30.0
# Tarde                      1  Fin de semana          6         30.0
# Tarde                      2    Día laboral          6         30.0
# Mañana                     2    Día laboral          6         30.0
# ...                      ...            ...        ...          ...
# Tarde                      1    Día laboral          6         20.0
# Noche                      2    Día laboral          6         30.0
# Tarde                      1    Día laboral          6         30.0
# Noche                      1    Día laboral          6         30.0
# Mañana                     1    Día laboral          3         70.0
#
#         Light_Conditions  Weather_Conditions  Road_Surface_Conditions  \
# Time
# Mañana                 1                   1                        1
# Mañana                 1                   1                        1
# Tarde                  1                   1                        1
# Tarde                  1                   1                        1
# Mañana                 1                   1                        1
# ...                  ...                 ...                      ...
# Tarde                  1                   1                        2
# Noche                  1                   1                        1
# Tarde                  4                   5                        2
# Noche                  1                   1                        1
# Mañana                 1                   1                        1
#
#         Urban_or_Rural_Area Vehicle_Type  \
# Time
# Mañana                    1         bike
# Mañana                    1         bike
# Tarde                     1         bike
# Tarde                     1         bike
# Mañana                    1         bike
# ...                     ...          ...
# Tarde                     1         bike
# Noche                     2         bike
# Tarde                     1         bike
# Noche                     1         bike
# Mañana                    1         bike
#
#         Did_Police_Officer_Attend_Scene_of_Accident  Junction_Detail  \
# Time
# Mañana                                            1                3
# Mañana                                            1                0
# Tarde                                             1                3
# Tarde                                             1                6
# Mañana                                            1                6
# ...                                             ...              ...
# Tarde                                             1                9
# Noche                                             2                0
# Tarde                                             2                3
# Noche                                             1                6
# Mañana                                            2                0
#
#         Number_of_Vehicles  Accident_Severity  Unnamed: 14
# Time
# Mañana                   1                  3          NaN
# Mañana                   1                  3          NaN
# Tarde                    1                  3          NaN
# Tarde                    1                  2          NaN
# Mañana                   1                  3          NaN
# ...                    ...                ...          ...
# Tarde                    1                  3          NaN
# Noche                    1                  2          NaN
# Tarde                    1                  2          NaN
# Noche                    1                  3          NaN
# Mañana                   1                  2          NaN
#
# [5338 rows x 14 columns]

# %%
# Completitud

(df_roads.isnull().sum() / df_roads.shape[0]).sort_values(ascending = False)
# Out:
# Unnamed: 14                                    1.000000
# Day_of_Week                                    0.003559
# Number_of_Casualties                           0.000000
# Road_Type                                      0.000000
# Speed_limit                                    0.000000
# Light_Conditions                               0.000000
# Weather_Conditions                             0.000000
# Road_Surface_Conditions                        0.000000
# Urban_or_Rural_Area                            0.000000
# Vehicle_Type                                   0.000000
# Did_Police_Officer_Attend_Scene_of_Accident    0.000000
# Junction_Detail                                0.000000
# Number_of_Vehicles                             0.000000
# Accident_Severity                              0.000000
# dtype: float64

# %%
# Unicidad
df_roads.loc[df_roads.duplicated(subset = df_roads.columns[1:], keep = False)].sort_values(by = "Time")
# Out:
#            Number_of_Casualties    Day_of_Week  Road_Type  Speed_limit  \
# Time
# Madrugada                     1  Fin de semana          6         30.0
# Madrugada                     1            NaN          6         30.0
# Madrugada                     1    Día laboral          6         30.0
# Madrugada                     1    Día laboral          6         30.0
# Mañana                        1    Día laboral          6         30.0
# ...                         ...            ...        ...          ...
# Tarde                         2  Fin de semana          6         30.0
# Tarde                         1    Día laboral          6         30.0
# Tarde                         1    Día laboral          6         30.0
# Tarde                         1    Día laboral          6         30.0
# Tarde                         2    Día laboral          6         30.0
#
#            Light_Conditions  Weather_Conditions  Road_Surface_Conditions  \
# Time
# Madrugada                 4                   1                        1
# Madrugada                 4                   1                        1
# Madrugada                 1                   1                        1
# Madrugada                 4                   1                        1
# Mañana                    1                   1                        1
# ...                     ...                 ...                      ...
# Tarde                     1                   1                        1
# Tarde                     1                   1                        2
# Tarde                     1                   1                        1
# Tarde                     1                   1                        1
# Tarde                     1                   1                        2
#
#            Urban_or_Rural_Area Vehicle_Type  \
# Time
# Madrugada                    1         bike
# Madrugada                    1         bike
# Madrugada                    1         bike
# Madrugada                    1         bike
# Mañana                       1         bike
# ...                        ...          ...
# Tarde                        1         bike
# Tarde                        1         bike
# Tarde                        1         bike
# Tarde                        1         bike
# Tarde                        1         bike
#
#            Did_Police_Officer_Attend_Scene_of_Accident  Junction_Detail  \
# Time
# Madrugada                                            1                3
# Madrugada                                            1                0
# Madrugada                                            1                9
# Madrugada                                            1                0
# Mañana                                               1                3
# ...                                                ...              ...
# Tarde                                                1                0
# Tarde                                                1                3
# Tarde                                                1                6
# Tarde                                                1                6
# Tarde                                                1                0
#
#            Number_of_Vehicles  Accident_Severity  Unnamed: 14
# Time
# Madrugada                   1                  3          NaN
# Madrugada                   1                  3          NaN
# Madrugada                   1                  3          NaN
# Madrugada                   1                  3          NaN
# Mañana                      1                  3          NaN
# ...                       ...                ...          ...
# Tarde                       1                  2          NaN
# Tarde                       1                  2          NaN
# Tarde                       1                  3          NaN
# Tarde                       1                  3          NaN
# Tarde                       1                  3          NaN
#
# [4375 rows x 14 columns]

# %%
# Número de resgistros duplicados
# TODO tiene sentido tener todos estos valores repetidos?
print('Total de registros repetidos:', df_roads.loc[df_roads.duplicated(subset = df_roads.columns[1:], keep = False)].shape[0])
# Out:
# Total de registros repetidos: 4375

# %%
# Consistencia
df_roads.groupby(['Time', 'Day_of_Week']).size()
# Out:
# Time       Day_of_Week
# Madrugada  Día laboral         3
#            Fin de semana       1
# Mañana     Día laboral      1249
#            Fin de semana     429
# Noche      Día laboral      1041
#            Fin de semana     428
# Tarde      Día laboral      1539
#            Fin de semana     629
# dtype: int64
